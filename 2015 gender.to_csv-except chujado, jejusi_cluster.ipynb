# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# u'C:\\Users\\user1345'

# %%
cd dat/2015/250m gender/250m gender
# Out:
# C:\Users\user1345\dat\2015\250m gender\250m gender

# %%
coords_df = pd.read_csv('250m.txt')
jan_df = pd.read_csv('jan.txt')
jan_df
# Out:
#        ﻿"STD_YM"    ID_250        M10        M20        M30         M40  \
# 0         201501  나나98C99C   2.512258   4.243226  13.005806   18.674839
# 1         201501  나다98A00C   0.554194   0.992581   3.384516    4.868710
# 2         201501  나나98C99D   0.206774   0.255484   1.756774    3.021290
# 3         201501  나다98A00D   0.191935   0.241613   1.053226    1.849677
# 4         201501  나나96C91A   0.146774   0.327742   1.021290    1.681613
# 5         201501  나나96C90B   0.138065   0.306452   0.911935    1.416452
# 6         201501  나나96D90B   0.875161   1.947742   6.055161    9.902581
# 7         201501  나나96D90D   0.138710   0.307419   0.929677    1.473871
# 8         201501  나나96A91D   0.664194   1.336774   3.991613    6.370323
# 9         201501  나나96B91D   2.837097   6.215806  19.338710   31.180968
# 10        201501  나나96C91D   2.216452   3.923871  11.193548   17.899677
# 11        201501  나나97A91A   1.866129   3.905161  11.581613   18.268065
# ...

# %%
new_df = coords_df.rename(columns={'SPO_NO_250':'ID_250'})

# %%
jan_df["month"] = "jan"

# %%
df0 = pd.merge(new_df, jan_df)

# %%
df = pd.DataFrame(columns=jan_df.columns)
df
# Out:
# Empty DataFrame
# Columns: [﻿"STD_YM", ID_250, M10, M20, M30, M40, M50, M60, W10, W20, W30, W40, W50, W60, M10_PROP, M20_PROP, M30_PROP, M40_PROP, M50_PROP, M60_PROP, W10_PROP, W20_PROP, W30_PROP, W40_PROP, W50_PROP, W60_PROP, month]
# Index: []
#
# [0 rows x 27 columns]

# %%
month = ["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep"]

# %%
jan_df.index = jan_df.ID_250

# %%
jan_df
# Out:
#           ﻿"STD_YM"    ID_250        M10        M20        M30         M40  \
# ID_250
# 나나98C99C     201501  나나98C99C   2.512258   4.243226  13.005806   18.674839
# 나다98A00C     201501  나다98A00C   0.554194   0.992581   3.384516    4.868710
# 나나98C99D     201501  나나98C99D   0.206774   0.255484   1.756774    3.021290
# 나다98A00D     201501  나다98A00D   0.191935   0.241613   1.053226    1.849677
# 나나96C91A     201501  나나96C91A   0.146774   0.327742   1.021290    1.681613
# 나나96C90B     201501  나나96C90B   0.138065   0.306452   0.911935    1.416452
# 나나96D90B     201501  나나96D90B   0.875161   1.947742   6.055161    9.902581
# 나나96D90D     201501  나나96D90D   0.138710   0.307419   0.929677    1.473871
# 나나96A91D     201501  나나96A91D   0.664194   1.336774   3.991613    6.370323
# 나나96B91D     201501  나나96B91D   2.837097   6.215806  19.338710   31.180968
# 나나96C91D     201501  나나96C91D   2.216452   3.923871  11.193548   17.899677
# ...

# %%
df = pd.DataFrame(columns=jan_df.columns)
df
# Out:
# Empty DataFrame
# Columns: [﻿"STD_YM", ID_250, M10, M20, M30, M40, M50, M60, W10, W20, W30, W40, W50, W60, M10_PROP, M20_PROP, M30_PROP, M40_PROP, M50_PROP, M60_PROP, W10_PROP, W20_PROP, W30_PROP, W40_PROP, W50_PROP, W60_PROP, month]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.columns
# Out:
# Index([u'﻿"STD_YM"', u'ID_250', u'M10', u'M20', u'M30', u'M40', u'M50', u'M60',
#        u'W10', u'W20', u'W30', u'W40', u'W50', u'W60', u'M10_PROP',
#        u'M20_PROP', u'M30_PROP', u'M40_PROP', u'M50_PROP', u'M60_PROP',
#        u'W10_PROP', u'W20_PROP', u'W30_PROP', u'W40_PROP', u'W50_PROP',
#        u'W60_PROP', u'month'],
#       dtype='object')

# %%
df = df.drop(df.columns[0], axis=1)
df.columns
# Out:
# Index([u'ID_250', u'M10', u'M20', u'M30', u'M40', u'M50', u'M60', u'W10',
#        u'W20', u'W30', u'W40', u'W50', u'W60', u'M10_PROP', u'M20_PROP',
#        u'M30_PROP', u'M40_PROP', u'M50_PROP', u'M60_PROP', u'W10_PROP',
#        u'W20_PROP', u'W30_PROP', u'W40_PROP', u'W50_PROP', u'W60_PROP',
#        u'month'],
#       dtype='object')

# %%
df = df.drop(df.columns[0], axis=1)
df.columns
# Out:
# Index([u'M10', u'M20', u'M30', u'M40', u'M50', u'M60', u'W10', u'W20', u'W30',
#        u'W40', u'W50', u'W60', u'M10_PROP', u'M20_PROP', u'M30_PROP',
#        u'M40_PROP', u'M50_PROP', u'M60_PROP', u'W10_PROP', u'W20_PROP',
#        u'W30_PROP', u'W40_PROP', u'W50_PROP', u'W60_PROP', u'month'],
#       dtype='object')

# %%
df = df.drop(df.columns[-1], axis=1)
df.columns
# Out:
# Index([u'M10', u'M20', u'M30', u'M40', u'M50', u'M60', u'W10', u'W20', u'W30',
#        u'W40', u'W50', u'W60', u'M10_PROP', u'M20_PROP', u'M30_PROP',
#        u'M40_PROP', u'M50_PROP', u'M60_PROP', u'W10_PROP', u'W20_PROP',
#        u'W30_PROP', u'W40_PROP', u'W50_PROP', u'W60_PROP'],
#       dtype='object')

# %%
for i in month:
    df2 = pd.read_csv('{mon}.txt'.format(mon=i))
    df2["month"] = i
    
    df = df.append(df2, ignore_index=True)

# %%
df
# Out:
#           ID_250        M10      M10_PROP        M20  M20_PROP        M30  \
# 0       나나98C99C   2.512258  2.857009e-04   4.243226  0.000186  13.005806
# 1       나다98A00C   0.554194  6.302442e-05   0.992581  0.000043   3.384516
# 2       나나98C99D   0.206774  2.351493e-05   0.255484  0.000011   1.756774
# 3       나다98A00D   0.191935  2.182743e-05   0.241613  0.000011   1.053226
# 4       나나96C91A   0.146774  1.669157e-05   0.327742  0.000014   1.021290
# 5       나나96C90B   0.138065  1.570108e-05   0.306452  0.000013   0.911935
# 6       나나96D90B   0.875161  9.952575e-05   1.947742  0.000085   6.055161
# 7       나나96D90D   0.138710  1.577445e-05   0.307419  0.000013   0.929677
# 8       나나96A91D   0.664194  7.553392e-05   1.336774  0.000059   3.991613
# 9       나나96B91D   2.837097  3.226425e-04   6.215806  0.000272  19.338710
# 10      나나96C91D   2.216452  2.520610e-04   3.923871  0.000172  11.193548
# 11      나나97A91A   1.866129  2.122213e-04   3.905161  0.000171  11.581613
# ...

# %%
man_df = df.groupby("ID_250").agg({"M10": np.sum, "M20": np.sum, "M30": np.sum, "M40": np.sum, "M50": np.sum, "M60": np.sum })
woman_df = df.groupby("ID_250").agg({"W10": np.sum, "W20": np.sum, "W30": np.sum, "W40": np.sum, "W50": np.sum, "W60": np.sum })

# %%
man_df
# Out:
#                 M60        M50        M40        M20        M30        M10
# ID_250
# 나나74C80B   1.941037   4.738571   5.423548   1.628894   3.920783   0.569078
# 나나74C80C   4.964251   5.775622   5.248641   0.916613   2.571866   0.376106
# 나나74D80C   2.576325   3.707350   3.715323   0.865092   2.206843   0.320829
# 나나74D80D   1.996866   1.693168   1.268433   0.046083   0.295737   0.043283
# 나나75A78C   3.953733   3.316336   2.506866   0.102166   0.621475   0.086567
# 나나75A78D   6.030599   5.269505   4.025300   0.208249   1.097212   0.149850
# 나나75A79C  14.449205  22.210645  23.471970   8.093387  16.841567   2.852926
# 나나75A79D  12.814988  16.780357  16.831267   5.198894  11.081647   1.866164
# 나나75A80D   4.806728   6.820242   6.885853   1.976014   4.596809   0.697984
# 나나75A82D   0.050323   0.088767   0.039482   0.000714   0.021636   0.020968
# 나나75A83C   0.011935   0.101152   0.134228   0.023687   0.160369   0.022650
# ...

# %%
woman_df.to_csv('wom.csv')
man_df.to_csv('man.csv')

# %%
coords_df
# Out:
#              ﻿XCoord          YCoord SPO_NO_250
# 0      884875.000122  1458875.000122   나나84D58D
# 1      885125.000122  1458875.000122   나나85D58A
# 2      884875.000122  1459125.000122   나나84A59D
# 3      885125.000122  1459125.000122   나나85A59A
# 4      884875.000122  1459375.000122   나나84B59D
# 5      885125.000122  1459375.000122   나나85B59A
# 6      884875.000122  1459625.000122   나나84C59D
# 7      885125.000122  1459625.000122   나나85C59A
# 8      885125.000122  1459875.000122   나나85D59A
# 9      885125.000122  1464375.000122   나나85B64A
# 10     885375.000122  1464375.000122   나나85B64B
# 11     885625.000122  1464375.000122   나나85B64C
# 12     885125.000122  1464625.000122   나나85C64A
# 13     885375.000122  1464625.000122   나나85C64B
# 14     885625.000122  1464625.000122   나나85C64C
# 15     885875.000122  1464625.000122   나나85C64D
# 16     886125.000122  1464625.000122   나나86C64A
# 17     884875.000122  1464875.000122   나나84D64D
# 18     885125.000122  1464875.000122   나나85D64A
# ...

# %%
new_df = coords_df.rename(columns={"SPO_NO_250": "ID_250"})

# %%
man_df
# Out:
#                 M60        M50        M40        M20        M30        M10
# ID_250
# 나나74C80B   1.941037   4.738571   5.423548   1.628894   3.920783   0.569078
# 나나74C80C   4.964251   5.775622   5.248641   0.916613   2.571866   0.376106
# 나나74D80C   2.576325   3.707350   3.715323   0.865092   2.206843   0.320829
# 나나74D80D   1.996866   1.693168   1.268433   0.046083   0.295737   0.043283
# 나나75A78C   3.953733   3.316336   2.506866   0.102166   0.621475   0.086567
# 나나75A78D   6.030599   5.269505   4.025300   0.208249   1.097212   0.149850
# 나나75A79C  14.449205  22.210645  23.471970   8.093387  16.841567   2.852926
# 나나75A79D  12.814988  16.780357  16.831267   5.198894  11.081647   1.866164
# 나나75A80D   4.806728   6.820242   6.885853   1.976014   4.596809   0.697984
# 나나75A82D   0.050323   0.088767   0.039482   0.000714   0.021636   0.020968
# 나나75A83C   0.011935   0.101152   0.134228   0.023687   0.160369   0.022650
# ...

# %%
co_df = pd.merge(new_df, df)
co_df
# Out:
#               ﻿XCoord          YCoord    ID_250       M10      M10_PROP  \
# 0       885375.000122  1464625.000122  나나85C64B  1.442903  1.640909e-04
# 1       885375.000122  1464625.000122  나나85C64B  1.118571  1.621855e-04
# 2       885375.000122  1464625.000122  나나85C64B  0.684839  1.165661e-04
# 3       885375.000122  1464625.000122  나나85C64B  1.570000  1.719270e-04
# 4       885375.000122  1464625.000122  나나85C64B  1.830000  1.455950e-04
# 5       885375.000122  1464625.000122  나나85C64B  0.660000  1.201453e-04
# 6       885375.000122  1464625.000122  나나85C64B  0.660000  1.004347e-04
# 7       885375.000122  1464625.000122  나나85C64B  1.060000  1.614741e-04
# 8       885375.000122  1464625.000122  나나85C64B  0.620000  9.078267e-05
# 9       886125.000122  1464625.000122  나나86C64A  0.003871  4.402171e-07
# 10      886125.000122  1464625.000122  나나86C64A  0.004286  6.214003e-07
# 11      886125.000122  1464625.000122  나나86C64A  0.001290  2.196253e-07
# ...

# %%
co_df.columns
# Out:
# Index([u'﻿XCoord', u'YCoord', u'ID_250', u'M10', u'M10_PROP', u'M20',
#        u'M20_PROP', u'M30', u'M30_PROP', u'M40', u'M40_PROP', u'M50',
#        u'M50_PROP', u'M60', u'M60_PROP', u'W10', u'W10_PROP', u'W20',
#        u'W20_PROP', u'W30', u'W30_PROP', u'W40', u'W40_PROP', u'W50',
#        u'W50_PROP', u'W60', u'W60_PROP', u'month', u'﻿"STD_YM"'],
#       dtype='object')

# %%
df
# Out:
#           ID_250        M10      M10_PROP        M20  M20_PROP        M30  \
# 0       나나98C99C   2.512258  2.857009e-04   4.243226  0.000186  13.005806
# 1       나다98A00C   0.554194  6.302442e-05   0.992581  0.000043   3.384516
# 2       나나98C99D   0.206774  2.351493e-05   0.255484  0.000011   1.756774
# 3       나다98A00D   0.191935  2.182743e-05   0.241613  0.000011   1.053226
# 4       나나96C91A   0.146774  1.669157e-05   0.327742  0.000014   1.021290
# 5       나나96C90B   0.138065  1.570108e-05   0.306452  0.000013   0.911935
# 6       나나96D90B   0.875161  9.952575e-05   1.947742  0.000085   6.055161
# 7       나나96D90D   0.138710  1.577445e-05   0.307419  0.000013   0.929677
# 8       나나96A91D   0.664194  7.553392e-05   1.336774  0.000059   3.991613
# 9       나나96B91D   2.837097  3.226425e-04   6.215806  0.000272  19.338710
# 10      나나96C91D   2.216452  2.520610e-04   3.923871  0.000172  11.193548
# 11      나나97A91A   1.866129  2.122213e-04   3.905161  0.000171  11.581613
# ...

# %%
man50_df = df.groupby("ID_250").agg({"M50": np.sum})

man50_df["ID_250"] = man50_df.index

# %%
man50_df
# Out:
#                 M50    ID_250
# ID_250
# 나나74C80B   4.738571  나나74C80B
# 나나74C80C   5.775622  나나74C80C
# 나나74D80C   3.707350  나나74D80C
# 나나74D80D   1.693168  나나74D80D
# 나나75A78C   3.316336  나나75A78C
# 나나75A78D   5.269505  나나75A78D
# 나나75A79C  22.210645  나나75A79C
# 나나75A79D  16.780357  나나75A79D
# 나나75A80D   6.820242  나나75A80D
# 나나75A82D   0.088767  나나75A82D
# 나나75A83C   0.101152  나나75A83C
# 나나75A84D   0.765968  나나75A84D
# 나나75B78C   5.120369  나나75B78C
# 나나75B78D   0.850000  나나75B78D
# 나나75B79D  13.077247  나나75B79D
# 나나75B80C  16.622143  나나75B80C
# 나나75B80D  13.803825  나나75B80D
# 나나75B82C   0.004977  나나75B82C
# 나나75B82D   0.040000  나나75B82D
# 나나75B83C   0.483652  나나75B83C
# 나나75C78C   2.379286  나나75C78C
# 나나75C78D   4.175000  나나75C78D
# 나나75C79D  13.660196  나나75C79D
# 나나75C80C   9.654585  나나75C80C
# 나나75C80D  16.861164  나나75C80D
# 나나75C83C   0.744574  나나75C83C
# 나나75C83D   0.674251  나나75C83D
# 나나75D77C   1.138353  나나75D77C
# 나나75D77D   4.590518  나나75D77D
# ...

# %%
ma50_df = pd.merge(new_df, man50_df)
ma50_df
# Out:
#              ﻿XCoord          YCoord    ID_250         M50
# 0      885375.000122  1464625.000122  나나85C64B   54.762719
# 1      886125.000122  1464625.000122  나나86C64A    3.172961
# 2      885125.000122  1464875.000122  나나85D64A   32.598214
# 3      885375.000122  1464875.000122  나나85D64B   96.374263
# 4      886125.000122  1464875.000122  나나86D64A    3.172961
# 5      885125.000122  1465125.000122  나나85A65A  151.479896
# 6      885375.000122  1465125.000122  나나85A65B  116.264758
# 7      885875.000122  1465125.000122  나나85A65D    3.273606
# 8      885125.000122  1465375.000122  나나85B65A  331.936740
# 9      885375.000122  1465375.000122  나나85B65B  296.124067
# 10     885625.000122  1465375.000122  나나85B65C    2.820000
# 11     886875.000122  1467875.000122  나나86D67D    2.788986
# 12     887125.000122  1467875.000122  나나87D67A    8.356959
# 13     884875.000122  1468125.000122  나나84A68D    0.388410
# 14     885125.000122  1468125.000122  나나85A68A    1.057730
# ...

# %%
ma50_df["M50"] > 20
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
# 5         True
# 6         True
# 7        False
# 8         True
# 9         True
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 15239     True
# 15240    False
# 15241    False
# 15242    False
# 15243    False
# 15244    False
# 15245    False
# 15246    False
# 15247     True
# 15248    False
# 15249     True
# 15250    False
# 15251    False
# 15252    False
# 15253    False
# 15254     True
# 15255     True
# 15256     True
# 15257    False
# 15258    False
# 15259     True
# 15260     True
# 15261     True
# 15262     True
# 15263     True
# 15264     True
# 15265     True
# ...

# %%
mans50_df = ma50_df[ma50_df["M50"] > 20]

# %%
mans50_df
# Out:
#              ﻿XCoord          YCoord    ID_250         M50
# 0      885375.000122  1464625.000122  나나85C64B   54.762719
# 2      885125.000122  1464875.000122  나나85D64A   32.598214
# 3      885375.000122  1464875.000122  나나85D64B   96.374263
# 5      885125.000122  1465125.000122  나나85A65A  151.479896
# 6      885375.000122  1465125.000122  나나85A65B  116.264758
# 8      885125.000122  1465375.000122  나나85B65A  331.936740
# 9      885375.000122  1465375.000122  나나85B65B  296.124067
# 16     885625.000122  1468125.000122  나나85A68C   32.138802
# 81     883625.000122  1470125.000122  나나83A70C   27.504654
# 93     883625.000122  1470375.000122  나나83B70C   47.383652
# 108    883375.000122  1470625.000122  나나83C70B   80.585184
# 109    883625.000122  1470625.000122  나나83C70C   95.962085
# 110    883875.000122  1470625.000122  나나83C70D  189.812592
# 111    884125.000122  1470625.000122  나나84C70A  272.176313
# 112    884375.000122  1470625.000122  나나84C70B   69.749355
# ...

# %%
mans50_df[mans50_df.columns[0]].mean()
# Out:
# 909985.1584334158

# %%
mans50_df[mans50_df.columns[1]].mean()
# Out:
# 1491223.5677813238

# %%
mans50_df.head()
# Out:
#          ﻿XCoord          YCoord    ID_250         M50
# 0  885375.000122  1464625.000122  나나85C64B   54.762719
# 2  885125.000122  1464875.000122  나나85D64A   32.598214
# 3  885375.000122  1464875.000122  나나85D64B   96.374263
# 5  885125.000122  1465125.000122  나나85A65A  151.479896
# 6  885375.000122  1465125.000122  나나85A65B  116.264758

# %%
(mans50_df[mans50_df.columns[0]] > 883000)\
    & (mans50_df[mans50_df.columns[0]] < 897000)\
    & (mans50_df[mans50_df.columns[1]] > 1544612)\
    & (mans50_df[mans50_df.columns[1]] < 1558541)
# Out:
# 0        False
# 2        False
# 3        False
# 5        False
# 6        False
# 8        False
# 9        False
# 16       False
# 81       False
# 93       False
# 108      False
# 109      False
# 110      False
# 111      False
# 112      False
# 126      False
# 127      False
# 128      False
# 129      False
# 130      False
# 144      False
# 145      False
# 146      False
# 147      False
# 148      False
# 149      False
# 150      False
# 160      False
# 164      False
# 165      False
#          ...
# 15134    False
# 15135    False
# 15136    False
# 15143    False
# 15160    False
# 15161    False
# 15162    False
# 15165    False
# 15171    False
# 15210     True
# 15211     True
# 15219     True
# 15225     True
# 15231     True
# 15232     True
# 15233     True
# 15239     True
# 15247     True
# 15249     True
# 15254     True
# 15255     True
# 15256     True
# 15259     True
# 15260     True
# 15261     True
# 15262     True
# 15263     True
# ...

# %%
((mans50_df[mans50_df.columns[0]] < 886636)|(mans50_df[mans50_df.columns[0]] > 893124))|(mans50_df[mans50_df.columns[1]] < 1543000)
# Out:
# 0         True
# 2         True
# 3         True
# 5         True
# 6         True
# 8         True
# 9         True
# 16        True
# 81        True
# 93        True
# 108       True
# 109       True
# 110       True
# 111       True
# 112       True
# 126       True
# 127       True
# 128       True
# 129       True
# 130       True
# 144       True
# 145       True
# 146       True
# 147       True
# 148       True
# 149       True
# 150       True
# 160       True
# 164       True
# 165       True
#          ...
# 15134     True
# 15135     True
# 15136     True
# 15143     True
# 15160     True
# 15161     True
# 15162     True
# 15165     True
# 15171     True
# 15210    False
# 15211    False
# 15219    False
# 15225    False
# 15231    False
# 15232    False
# 15233    False
# 15239    False
# 15247    False
# 15249    False
# 15254    False
# 15255    False
# 15256    False
# 15259    False
# 15260    False
# 15261    False
# 15262    False
# 15263    False
# ...

# %%
mans50s_df = mans50_df[((mans50_df[mans50_df.columns[0]] < 886636)|(mans50_df[mans50_df.columns[0]] > 893124))|\
                       (mans50_df[mans50_df.columns[1]] < 1543000)]

# %%
mans50s_df
# Out:
#              ﻿XCoord          YCoord    ID_250         M50
# 0      885375.000122  1464625.000122  나나85C64B   54.762719
# 2      885125.000122  1464875.000122  나나85D64A   32.598214
# 3      885375.000122  1464875.000122  나나85D64B   96.374263
# 5      885125.000122  1465125.000122  나나85A65A  151.479896
# 6      885375.000122  1465125.000122  나나85A65B  116.264758
# 8      885125.000122  1465375.000122  나나85B65A  331.936740
# 9      885375.000122  1465375.000122  나나85B65B  296.124067
# 16     885625.000122  1468125.000122  나나85A68C   32.138802
# 81     883625.000122  1470125.000122  나나83A70C   27.504654
# 93     883625.000122  1470375.000122  나나83B70C   47.383652
# 108    883375.000122  1470625.000122  나나83C70B   80.585184
# 109    883625.000122  1470625.000122  나나83C70C   95.962085
# 110    883875.000122  1470625.000122  나나83C70D  189.812592
# 111    884125.000122  1470625.000122  나나84C70A  272.176313
# 112    884375.000122  1470625.000122  나나84C70B   69.749355
# ...

# %%
mans50s_df.columns
# Out:
# Index([u'﻿XCoord', u'YCoord', u'ID_250', u'M50'], dtype='object')

# %%
mans50s_df = mans50s_df[((mans50_df[mans50_df.columns[0]] < 902800)|(mans50_df[mans50_df.columns[0]] > 914500))|\
                       ((mans50_df[mans50_df.columns[1]] < 1498000)|(mans50_df[mans50_df.columns[1]] > 1504900))]
# Out:
# C:\Anaconda2\lib\site-packages\pandas\core\frame.py:1997: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
mans50s_df
# Out:
#              ﻿XCoord          YCoord    ID_250         M50
# 0      885375.000122  1464625.000122  나나85C64B   54.762719
# 2      885125.000122  1464875.000122  나나85D64A   32.598214
# 3      885375.000122  1464875.000122  나나85D64B   96.374263
# 5      885125.000122  1465125.000122  나나85A65A  151.479896
# 6      885375.000122  1465125.000122  나나85A65B  116.264758
# 8      885125.000122  1465375.000122  나나85B65A  331.936740
# 9      885375.000122  1465375.000122  나나85B65B  296.124067
# 16     885625.000122  1468125.000122  나나85A68C   32.138802
# 81     883625.000122  1470125.000122  나나83A70C   27.504654
# 93     883625.000122  1470375.000122  나나83B70C   47.383652
# 108    883375.000122  1470625.000122  나나83C70B   80.585184
# 109    883625.000122  1470625.000122  나나83C70C   95.962085
# 110    883875.000122  1470625.000122  나나83C70D  189.812592
# 111    884125.000122  1470625.000122  나나84C70A  272.176313
# 112    884375.000122  1470625.000122  나나84C70B   69.749355
# ...

# %%
mans50s_df[mans50s_df.columns[0]].mean
# Out:
# <bound method Series.mean of 0        885375.000122
# 2        885125.000122
# 3        885375.000122
# 5        885125.000122
# 6        885375.000122
# 8        885125.000122
# 9        885375.000122
# 16       885625.000122
# 81       883625.000122
# 93       883625.000122
# 108      883375.000122
# 109      883625.000122
# 110      883875.000122
# 111      884125.000122
# 112      884375.000122
# 126      883375.000122
# 127      883625.000122
# 128      883875.000122
# 129      884125.000122
# 130      884375.000122
# 144      883125.000122
# 145      883375.000122
# 146      883625.000122
# 147      883875.000122
# 148      884125.000122
# 149      884375.000122
# 150      884625.000122
# 160      887625.000122
# 164      904125.000122
# 165      904375.000122
#              ...
# 15054    930875.000122
# 15055    931125.000122
# 15057    931625.000122
# 15058    931875.000122
# 15059    932125.000122
# 15069    934625.000122
# 15070    934875.000122
# 15084    926375.000122
# ...

# %%
list = zip((mans50s_df[mans50s_df.columns[0]] - 909985.1584334158), (mans50s_df[mans50s_df.columns[1]] - 1491223.5677813238))
list
# Out:
# [(-24610.158311345847, -26598.56765925372),
#  (-24860.158311345847, -26348.56765925372),
#  (-24610.158311345847, -26348.56765925372),
#  (-24860.158311345847, -26098.56765925372),
#  (-24610.158311345847, -26098.56765925372),
#  (-24860.158311345847, -25848.56765925372),
#  (-24610.158311345847, -25848.56765925372),
#  (-24360.158311345847, -23098.56765925372),
#  (-26360.158311345847, -21098.56765925372),
#  (-26360.158311345847, -20848.56765925372),
#  (-26610.158311345847, -20598.56765925372),
#  (-26360.158311345847, -20598.56765925372),
#  (-26110.158311345847, -20598.56765925372),
#  (-25860.158311345847, -20598.56765925372),
#  (-25610.158311345847, -20598.56765925372),
#  (-26610.158311345847, -20348.56765925372),
#  (-26360.158311345847, -20348.56765925372),
#  (-26110.158311345847, -20348.56765925372),
#  (-25860.158311345847, -20348.56765925372),
#  (-25610.158311345847, -20348.56765925372),
#  (-26860.158311345847, -20098.56765925372),
# ...

# %%
X = np.array(list)

# %%
X
# Out:
# array([[-24610.15831135, -26598.56765925],
#        [-24860.15831135, -26348.56765925],
#        [-24610.15831135, -26348.56765925],
#        ...,
#        [ 20889.84168865,  16401.43234075],
#        [ 21639.84168865,  16401.43234075],
#        [ 24389.84168865,  16401.43234075]])

# %%
plt.scatter(X[:, 0], X[:, 1], s=100);

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=40, init="random", n_init=1, max_iter=1, random_state=0).fit(X)

# %%
color = mpl.colors.cnames.keys()

# %%
for i, j in zip(model.cluster_centers_, range(40)):
    print(i[0])
    print(j)
# Out:
# -20167.850619
# 0
# 1577.34168865
# 1
# -24860.1583113
# 2
# -3710.15831135
# 3
# -8235.15831135
# 4
# 3008.26274129
# 5
# -23993.4916447
# 6
# -31010.1583113
# 7
# -17976.824978
# 8
# 8981.1878425
# 9
# -26544.3688377
# 10
# -13485.1583113
# 11
# 13379.2783084
# 12
# -4100.54292673
# 13
# 7985.07978389
# 14
# -23582.3805336
# 15
# 10181.5083553
# 16
# -24651.824978
# 17
# -24975.5429267
# 18
# -3398.03709922
# 19
# 8581.50835532
# 20
# 26008.4548273
# 21
# -25982.7389565
# 22
# 2851.74645056
# 23
# 13893.0468169
# 24
# -12407.3281227
# 25
# 6151.74645056
# 26
# 2339.84168865
# 27
# -10922.6583113
# 28
# 4961.27026008
# 29
# 3851.96290078
# 30
# 36165.5559744
# 31
# 20614.3314846
# 32
# 27964.3097738
# 33
# -651.824978013
# 34
# 10729.5852784
# 35
# -4228.97019253
# 36
# 18406.5083553
# 37
# -15540.6094392
# 38
# 5342.96668865
# 39

# %%
c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30,\
c31, c32, c33, c34, c35, c36, c37, c38, c39 = model.cluster_centers_
for i, j in zip(model.cluster_centers_, range(40)):
    plt.scatter(X[model.labels_== j,0], X[model.labels_==j,1], s=100, marker='v', color=color[j]);
    plt.scatter(i[0], i[1], s=100, c=color[j])

# %%
def kmeans_df(c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, \
             c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, c39):
    df = pd.DataFrame(np.hstack([X, 
                                
                                model.labels_[:, np.newaxis]]),
                    columns=["x0", "x1", "c"])
    return df

cl_df = kmeans_df(c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, \
             c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, c39)

# %%
cl_df
# Out:
#                 x0            x1   c
# 0    -24610.158311 -26598.567659  22
# 1    -24860.158311 -26348.567659  22
# 2    -24610.158311 -26348.567659  22
# 3    -24860.158311 -26098.567659  22
# 4    -24610.158311 -26098.567659  22
# 5    -24860.158311 -25848.567659  22
# 6    -24610.158311 -25848.567659  22
# 7    -24360.158311 -23098.567659  22
# 8    -26360.158311 -21098.567659  22
# 9    -26360.158311 -20848.567659  22
# 10   -26610.158311 -20598.567659  22
# 11   -26360.158311 -20598.567659  22
# 12   -26110.158311 -20598.567659  22
# 13   -25860.158311 -20598.567659  22
# 14   -25610.158311 -20598.567659  22
# 15   -26610.158311 -20348.567659  22
# 16   -26360.158311 -20348.567659  22
# 17   -26110.158311 -20348.567659  22
# 18   -25860.158311 -20348.567659  22
# 19   -25610.158311 -20348.567659  22
# 20   -26860.158311 -20098.567659  22
# 21   -26610.158311 -20098.567659  22
# 22   -26360.158311 -20098.567659  22
# 23   -26110.158311 -20098.567659  22
# ...

# %%
cl_df[cl_df["c"] == 5]
# Out:
#                x0           x1  c
# 1169  1639.841689  1151.432341  5
# 1182  1389.841689  1401.432341  5
# 1183  1639.841689  1401.432341  5
# 1184  1889.841689  1401.432341  5
# 1185  2139.841689  1401.432341  5
# 1198   139.841689  1651.432341  5
# 1199  1139.841689  1651.432341  5
# 1200  1389.841689  1651.432341  5
# 1201  1639.841689  1651.432341  5
# 1202  1889.841689  1651.432341  5
# 1203  2139.841689  1651.432341  5
# 1204  2389.841689  1651.432341  5
# 1205  2639.841689  1651.432341  5
# 1215   139.841689  1901.432341  5
# 1216   389.841689  1901.432341  5
# 1217   889.841689  1901.432341  5
# 1218  2389.841689  1901.432341  5
# 1219  2639.841689  1901.432341  5
# 1235  2389.841689  2151.432341  5
# 1236  2639.841689  2151.432341  5
# 1237  5639.841689  2151.432341  5
# 1238  5889.841689  2151.432341  5
# 1239  6139.841689  2151.432341  5
# 1250  2389.841689  2401.432341  5
# 1251  2639.841689  2401.432341  5
# 1252  5389.841689  2401.432341  5
# ...

# %%
cluster_df = cl_df.groupby("c").agg({
        'x1' : [np.size,]
    })
cluster_df
# Out:
#      x1
#    size
# c
# 0    66
# 1    12
# 2    33
# 3    21
# 4    61
# 5    44
# 6    24
# 7    35
# 8    43
# 9    43
# 10   48
# 11   53
# 12   67
# 13   69
# 14   20
# 15   11
# 16   15
# 17   13
# 18   13
# 19   30
# 20   44
# 21  118
# 22  130
# 23  105
# 24   81
# 25  170
# 26   20
# 27   33
# 28   61
# 29    9
# 30   34
# 31  174
# 32   45
# 33   47
# 34    8
# 35   59
# 36   84
# 37   44
# 38  103
# 39   15

# %%
c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30,\
c31, c32, c33, c34, c35, c36, c37, c38, c39 = model.cluster_centers_
for i, j in zip(model.cluster_centers_, range(40)):
    plt.scatter(X[model.labels_== j,0], X[model.labels_==j,1], s=100, marker='v', color=color[j]);
    plt.scatter(i[0], i[1], s=100, c=color[j])

# %%
22, 23, 25, 31, 38

# %%
c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30,\
c31, c32, c33, c34, c35, c36, c37, c38, c39 = model.cluster_centers_
for i, j in zip(model.cluster_centers_, range(40)):
    if j in [22, 23, 25, 31, 38]:
        plt.scatter(X[model.labels_== j,0], X[model.labels_==j,1], s=100, marker='v', color=color[j]);
        plt.scatter(i[0], i[1], s=100, c=color[j])
    else:
        plt.scatter(X[model.labels_== j,0], X[model.labels_==j,1], s=100, marker='^', color='white');
        plt.scatter(i[0], i[1], s=100, c='black')

# %%
c0, c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30,\
c31, c32, c33, c34, c35, c36, c37, c38, c39, c40, c41, c42, c43, c44, c45, c46, c47, c48, c49 = model.cluster_centers_
for i, j in zip(model.cluster_centers_, range(30)):
    plt.scatter(X[model.labels_== j,0], X[model.labels_==j,1], s=100, marker='v', color=color[j]);
    plt.scatter(i[0], i[1], s=100, c=color[j])

# %%
mans50_df
# Out:
#              ﻿XCoord          YCoord    ID_250         M50  cluster
# 0      885375.000122  1464625.000122  나나85C64B   54.762719       29
# 2      885125.000122  1464875.000122  나나85D64A   32.598214       29
# 3      885375.000122  1464875.000122  나나85D64B   96.374263       29
# 5      885125.000122  1465125.000122  나나85A65A  151.479896       29
# 6      885375.000122  1465125.000122  나나85A65B  116.264758       29
# 8      885125.000122  1465375.000122  나나85B65A  331.936740       29
# 9      885375.000122  1465375.000122  나나85B65B  296.124067       29
# 16     885625.000122  1468125.000122  나나85A68C   32.138802       29
# 81     883625.000122  1470125.000122  나나83A70C   27.504654       29
# 93     883625.000122  1470375.000122  나나83B70C   47.383652       29
# 108    883375.000122  1470625.000122  나나83C70B   80.585184       29
# 109    883625.000122  1470625.000122  나나83C70C   95.962085       29
# 110    883875.000122  1470625.000122  나나83C70D  189.812592       29
# ...

# %%
mans50_df[mans50_df["cluster"] == 1]
# Out:
# Empty DataFrame
# Columns: [﻿XCoord, YCoord, ID_250, M50, cluster]
# Index: []

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
from scipy.spatial import distance 
from scipy import stats
import seaborn as sns
import scipy

def euclidean_cdist(matrix, vector, dist):
    """
    Compute the cosine distances between each row of matrix and vector.
    """
    v = vector.reshape(1, -1)
    return scipy.spatial.distance.cdist(matrix, v, 'euclidean').reshape(-1)

def matrix_similarity( matrix_ds, dist='jaccard'):
    
    sim_mat = []
    name = []
    for idx, row in matrix_ds.iterrows():
        name.append(idx)
        sim_mat.append(cos_cdist( matrix_ds, row, dist ).tolist())
    ds = 1-pd.DataFrame(sim_mat, columns=name, index=name)
    return ds

# %%
## data 만들기
tmp_ds = df[df.target.isin(top_writer[:30].uid)]
writer_ds = pd.pivot_table( tmp_ds, index='target', columns='uid', values='dir', aggfunc=len, fill_value=0)
ds = matrix_similarity( writer_ds )

## 테마 셋팅
sns.set(style="whitegrid", palette="pastel", color_codes=True,font_scale=1.2)
cmap = sns.cubehelix_palette(as_cmap=True, rot=-.2, light=1.3)

## clustering & visualization
cm = sns.clustermap(ds, cmap=cmap, linewidths=.5)

## figure size 
cm.fig.set_figwidth(15)
cm.fig.set_figheight(15)

# %%
beer_1 = raw_input("Input the Beer name : ")
